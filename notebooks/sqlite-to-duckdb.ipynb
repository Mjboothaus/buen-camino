# %%
import duckdb
import pandas as pd
import folium

# %%
HEALTH_DB = "../data/healthkit-sqlite-2023-11-17-fix.db"

# %%
con = duckdb.connect(HEALTH_DB)

# %%
# con.install_extension("sqlite")

# %%
# con.load_extension("sqlite")

# %%
con.sql("PRAGMA show_tables")
# Out:
# ┌─────────────────────────────────┐
# │              name               │
# │             varchar             │
# ├─────────────────────────────────┤
# │ activity_summary                │
# │ rActiveEnergyBurned             │
# │ rAppleExerciseTime              │
# │ rAppleStandHour                 │
# │ rAppleStandTime                 │
# │ rAppleWalkingSteadiness         │
# │ rAudioExposureEvent             │
# │ rBasalEnergyBurned              │
# │ rBloodPressureDiastolic         │
# │ rBloodPressureSystolic          │
# │          ·                      │
# │          ·                      │
# │          ·                      │
# │ rSwimmingStrokeCount            │
# │ rTimeInDaylight                 │
# │ rVO2Max                         │
# │ rWalkingAsymmetryPercentage     │
# │ rWalkingDoubleSupportPercentage │
# │ rWalkingHeartRateAverage        │
# │ rWalkingSpeed                   │
# │ rWalkingStepLength              │
# │ workout_points                  │
# │ workouts                        │
# ├─────────────────────────────────┤
# │       43 rows (20 shown)        │
# └─────────────────────────────────┘

# %%
sqlite_db_tables_sql = "SELECT * FROM sqlite_schema WHERE type = 'table' AND name NOT LIKE 'sqlite_%';"

# %%
sqlitedbtables = con.sql(sqlite_db_tables_sql).to_df()

# %%
sqlitedbtables
# Out:
#      type                             name                         tbl_name  \
# 0   table                          rHeight                          rHeight
# 1   table                        rBodyMass                        rBodyMass
# 2   table                       rHeartRate                       rHeartRate
# 3   table                rOxygenSaturation                rOxygenSaturation
# 4   table           rBloodPressureSystolic           rBloodPressureSystolic
# 5   table          rBloodPressureDiastolic          rBloodPressureDiastolic
# 6   table                 rRespiratoryRate                 rRespiratoryRate
# 7   table                       rStepCount                       rStepCount
# 8   table          rDistanceWalkingRunning          rDistanceWalkingRunning
# 9   table               rBasalEnergyBurned               rBasalEnergyBurned
# 10  table              rActiveEnergyBurned              rActiveEnergyBurned
# 11  table                  rFlightsClimbed                  rFlightsClimbed
# 12  table               rAppleExerciseTime               rAppleExerciseTime
# 13  table                 rDistanceCycling                 rDistanceCycling
# 14  table                rDistanceSwimming                rDistanceSwimming
# 15  table             rSwimmingStrokeCount             rSwimmingStrokeCount
# 16  table                rRestingHeartRate                rRestingHeartRate
# 17  table                          rVO2Max                          rVO2Max
# 18  table         rWalkingHeartRateAverage         rWalkingHeartRateAverage
# 19  table      rEnvironmentalAudioExposure      rEnvironmentalAudioExposure
# 20  table          rHeadphoneAudioExposure          rHeadphoneAudioExposure
# 21  table  rWalkingDoubleSupportPercentage  rWalkingDoubleSupportPercentage
# 22  table       rSixMinuteWalkTestDistance       rSixMinuteWalkTestDistance
# 23  table                  rAppleStandTime                  rAppleStandTime
# 24  table                    rWalkingSpeed                    rWalkingSpeed
# 25  table               rWalkingStepLength               rWalkingStepLength
# 26  table      rWalkingAsymmetryPercentage      rWalkingAsymmetryPercentage
# 27  table                rStairAscentSpeed                rStairAscentSpeed
# 28  table               rStairDescentSpeed               rStairDescentSpeed
# 29  table     rHKDataTypeSleepDurationGoal     rHKDataTypeSleepDurationGoal
# 30  table          rAppleWalkingSteadiness          rAppleWalkingSteadiness
# 31  table      rHeartRateRecoveryOneMinute      rHeartRateRecoveryOneMinute
# 32  table     rEnvironmentalSoundReduction     rEnvironmentalSoundReduction
# 33  table                  rTimeInDaylight                  rTimeInDaylight
# 34  table                  rPhysicalEffort                  rPhysicalEffort
# 35  table                   rSleepAnalysis                   rSleepAnalysis
# 36  table                  rAppleStandHour                  rAppleStandHour
# 37  table                         workouts                         workouts
# 38  table                   workout_points                   workout_points
# 39  table                 activity_summary                 activity_summary
# 40  table                  rMindfulSession                  rMindfulSession
# 41  table              rAudioExposureEvent              rAudioExposureEvent
# 42  table        rHeartRateVariabilitySDNN        rHeartRateVariabilitySDNN
#
#     rootpage                                                sql
# 0          0  CREATE TABLE rHeight(startDate VARCHAR, endDat...
# 1          0  CREATE TABLE rBodyMass(startDate VARCHAR, endD...
# 2          0  CREATE TABLE rHeartRate(startDate VARCHAR, end...
# 3          0  CREATE TABLE rOxygenSaturation(startDate VARCH...
# 4          0  CREATE TABLE rBloodPressureSystolic(startDate ...
# 5          0  CREATE TABLE rBloodPressureDiastolic(startDate...
# 6          0  CREATE TABLE rRespiratoryRate(startDate VARCHA...
# 7          0  CREATE TABLE rStepCount(startDate VARCHAR, end...
# 8          0  CREATE TABLE rDistanceWalkingRunning(startDate...
# 9          0  CREATE TABLE rBasalEnergyBurned(startDate VARC...
# 10         0  CREATE TABLE rActiveEnergyBurned(startDate VAR...
# 11         0  CREATE TABLE rFlightsClimbed(startDate VARCHAR...
# 12         0  CREATE TABLE rAppleExerciseTime(startDate VARC...
# 13         0  CREATE TABLE rDistanceCycling(startDate VARCHA...
# 14         0  CREATE TABLE rDistanceSwimming(startDate VARCH...
# 15         0  CREATE TABLE rSwimmingStrokeCount(startDate VA...
# 16         0  CREATE TABLE rRestingHeartRate(startDate VARCH...
# 17         0  CREATE TABLE rVO2Max(startDate VARCHAR, endDat...
# 18         0  CREATE TABLE rWalkingHeartRateAverage(startDat...
# 19         0  CREATE TABLE rEnvironmentalAudioExposure(start...
# 20         0  CREATE TABLE rHeadphoneAudioExposure(startDate...
# 21         0  CREATE TABLE rWalkingDoubleSupportPercentage(s...
# 22         0  CREATE TABLE rSixMinuteWalkTestDistance(startD...
# 23         0  CREATE TABLE rAppleStandTime(startDate VARCHAR...
# 24         0  CREATE TABLE rWalkingSpeed(startDate VARCHAR, ...
# 25         0  CREATE TABLE rWalkingStepLength(startDate VARC...
# 26         0  CREATE TABLE rWalkingAsymmetryPercentage(start...
# 27         0  CREATE TABLE rStairAscentSpeed(startDate VARCH...
# 28         0  CREATE TABLE rStairDescentSpeed(startDate VARC...
# 29         0  CREATE TABLE rHKDataTypeSleepDurationGoal(star...
# 30         0  CREATE TABLE rAppleWalkingSteadiness(startDate...
# 31         0  CREATE TABLE rHeartRateRecoveryOneMinute(start...
# 32         0  CREATE TABLE rEnvironmentalSoundReduction(star...
# 33         0  CREATE TABLE rTimeInDaylight(startDate VARCHAR...
# 34         0  CREATE TABLE rPhysicalEffort(startDate VARCHAR...
# 35         0  CREATE TABLE rSleepAnalysis(startDate VARCHAR,...
# 36         0  CREATE TABLE rAppleStandHour(startDate VARCHAR...
# 37         0  CREATE TABLE workouts(id VARCHAR PRIMARY KEY, ...
# 38         0  CREATE TABLE workout_points(date VARCHAR, lati...
# 39         0  CREATE TABLE activity_summary(dateComponents V...
# 40         0  CREATE TABLE rMindfulSession(startDate VARCHAR...
# 41         0  CREATE TABLE rAudioExposureEvent(startDate VAR...
# 42         0  CREATE TABLE rHeartRateVariabilitySDNN(startDa...

# %%
sqlite_table_refs_sql = "SELECT sqlite_master.name FROM sqlite_master JOIN pragma_foreign_key_list(sqlite_master.name) as fk_info"

# %%
# sqlitetablerefs = con.sql(sqlite_table_refs_sql)

# %%
con_duck = duckdb.connect("../data/healthkit_duck.db")

# %%
sqlitedbtables["sql"].iloc[0]
# Out:
# 'CREATE TABLE rHeight(startDate VARCHAR, endDate VARCHAR, "value" VARCHAR, unit VARCHAR, sourceName VARCHAR, sourceVersion VARCHAR, creationDate VARCHAR, metadata_HKWasUserEntered VARCHAR);'

# %%
con_duck.sql(sqlitedbtables["sql"].iloc[0])

# %%
# WORK in PROGRESS

# e.g. see https://observablehq.com/@randomfractals/sqlite-to-duckdb

# %%
# Auto-generated code from Cursor 

""" 
import sqlite3
import duckdb

# Connect to the SQLite database
sqlite_conn = sqlite3.connect('sqlite_database.db')

# Create a cursor object
sqlite_cursor = sqlite_conn.cursor()

# Execute a query to fetch all the data from the SQLite database
sqlite_cursor.execute("SELECT * FROM table_name")
rows = sqlite_cursor.fetchall()

# Connect to the DuckDB database
duckdb_conn = duckdb.connect('duckdb_database.db')

# Create a cursor object
duckdb_cursor = duckdb_conn.cursor()

# Insert the data into the DuckDB database
duckdb_cursor.executemany("INSERT INTO table_name VALUES (?, ?, ?, ?)", rows)

# Commit the changes and close the connections
duckdb_conn.commit()
sqlite_conn.close()
duckdb_conn.close() """
# Out:
# ' \nimport sqlite3\nimport duckdb\n\n# Connect to the SQLite database\nsqlite_conn = sqlite3.connect(\'sqlite_database.db\')\n\n# Create a cursor object\nsqlite_cursor = sqlite_conn.cursor()\n\n# Execute a query to fetch all the data from the SQLite database\nsqlite_cursor.execute("SELECT * FROM table_name")\nrows = sqlite_cursor.fetchall()\n\n# Connect to the DuckDB database\nduckdb_conn = duckdb.connect(\'duckdb_database.db\')\n\n# Create a cursor object\nduckdb_cursor = duckdb_conn.cursor()\n\n# Insert the data into the DuckDB database\nduckdb_cursor.executemany("INSERT INTO table_name VALUES (?, ?, ?, ?)", rows)\n\n# Commit the changes and close the connections\nduckdb_conn.commit()\nsqlite_conn.close()\nduckdb_conn.close() '
